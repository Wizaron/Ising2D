# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
size=np.loadtxt('./uncorrelated/mean_observable_and_error',usecols=(0,2,3,5))
print size[:,1]
print size[:,2]
print size[:,3]
# Out:
# [  4.   4.   4.   4.   4.   4.   4.   4.   4.   4.   4.   4.   4.   4.   4.
#    4.   4.   4.   4.   8.   8.   8.   8.   8.   8.   8.   8.   8.   8.   8.
#    8.   8.   8.   8.   8.   8.   8.   8.  16.  16.  16.  16.  16.  16.  16.
#   16.  16.  16.  16.  16.  16.  16.  16.  16.  16.  16.  16.  24.  24.  24.
#   24.  24.  24.  24.  24.  24.  24.  24.  24.  24.  24.  24.  24.  24.  24.
#   24.]
# [ 0.982875  0.9565    0.9215    0.881375  0.862625  0.832125  0.829875
#   0.846125  0.83675   0.823125  0.811625  0.8125    0.799     0.782
#   0.782875  0.741875  0.701375  0.607125  0.585875  0.978344  0.958688
#   0.906875  0.811458  0.779583  0.79      0.763437  0.732396  0.741563
#   0.705937  0.679792  0.643125  0.67125   0.683125  0.633125  0.614688
#   0.454688  0.364583  0.339167  0.979401  0.958646  0.914349  0.803828
#   0.780339  0.750755  0.694792  0.6925    0.678776  0.595495  0.599635
#   0.449349  0.514974  0.408802  0.423802  0.433828  0.25776   0.207995
# ...

# %%
T=[1.6,1.8,2.0,2.2,2.225,2.250,2.275,2.300,2.325,2.350,2.375,2.400,2.425,2.450,2.475,2.5,2.7,2.9,3.1]
binder_ratio4 = size[0:19,3] / pow(size[0:19,2],2)
binder_ratio8 = size[19:38,3] /pow(size[19:38,2],2)
binder_ratio16 = size[38:57,3] / pow(size[38:57,2],2)
binder_ratio24 = size[57:76,3] /pow(size[57:76,2],2)

# %%
plt.plot(T,binder_ratio4,'r')
plt.plot(T,binder_ratio4,'ro')
plt.plot(T,binder_ratio8,'y')
plt.plot(T,binder_ratio8,'yo')
plt.plot(T,binder_ratio16,'g')
plt.plot(T,binder_ratio16,'go')
plt.plot(T,binder_ratio24,'b')
plt.plot(T,binder_ratio24,'bo')
plt.title(r'$Q$',fontsize=18)
plt.xlabel('$T$',fontsize=18)
plt.text(1.7,1.2, r'L=4',color='red',fontsize=12)
plt.text(1.7,1.25, r'L=8',color='yellow',fontsize=12)
plt.text(1.7,1.3, r'L=16',color='green',fontsize=12)
plt.text(1.7,1.35, r'L=24',color='blue',fontsize=12)
#plt.xlim(2.1,2.5)
#plt.ylim(0.2,4.07)
savefig('/Users/onurkaplan/dropbox/kaplan/programs/graphics/properties/binder_ratio_wolff.png')
plt.show()

# %%
plt.plot(T,binder_ratio4,'r')
plt.plot(T,binder_ratio4,'ro')
plt.plot(T,binder_ratio8,'y')
plt.plot(T,binder_ratio8,'yo')
plt.plot(T,binder_ratio16,'g')
plt.plot(T,binder_ratio16,'go')
plt.plot(T,binder_ratio24,'b')
plt.plot(T,binder_ratio24,'bo')
plt.title(r'$Q$',fontsize=18)
plt.xlabel('$T$',fontsize=18)
plt.text(2.2,1.2, r'L=4',color='red',fontsize=12)
plt.text(2.2,1.25, r'L=8',color='yellow',fontsize=12)
plt.text(2.2,1.3, r'L=16',color='green',fontsize=12)
plt.text(2.2,1.35, r'L=24',color='blue',fontsize=12)
plt.xlim(2.17,2.5)
plt.ylim(1.0,1.45)
savefig('/Users/onurkaplan/dropbox/kaplan/programs/graphics/properties/binder_ratio2_wolff.png')
plt.show()

# %%
import numpy as np

# %%
Temp = 2.269
J = 1.0 / Temp
H= 0.0
L = 32
N=L*L
Nobs = 4
Nsw=4000
filename='correlated'

# %%
auto=np.zeros(Nsw)
    
auto=np.loadtxt('%s/autocorrelation/autocorrelation_fnct_energy_J%.2f_L%i_H%.2f' %(filename , J, L,H))

# %%
print len(auto)
# Out:
# 4000

# %%
x=linspace(0,Nsw-1,Nsw)
plt.plot(x,auto)
plt.title('Autocorrelation Function vs MC Time per Site',fontsize=12)
plt.xlabel('MC Time per Site',fontsize=12)
#plt.text(310, 0.2, r' m =$ \frac{1}{N} \sum s_i$',fontsize=18)
#plt.xlim(0,2)
#plt.ylim(-1,0.01)
#savefig('/Users/onurkaplan/desktop/graphics/autocorrelation/autocorrelation_T%f.png' %Temp )
plt.show()

# %%
j=0
n_auto32=[]

while auto[j] > 0 :        
    n_auto32.append(auto[j])
    j = j+1

# %%
print len(n_auto32)
# Out:
# 215

# %%
print n_auto32[0]
# Out:
# 1.0

# %%
gg4=5
a4 = np.log(np.linspace(1,len(n_auto4)-1-gg4,len(n_auto4)-gg4))
gg8=24
a8 = np.log(np.linspace(1,len(n_auto8)-1-gg8,len(n_auto8)-gg8))
gg16=18
a16 = np.log(np.linspace(1,len(n_auto16)-1-gg16,len(n_auto16)-gg16))
gg32=152
a32 = np.log(np.linspace(1,len(n_auto32)-1-gg32,len(n_auto32)-gg32))

# %%
plt.plot(a4,n_auto4[0:len(n_auto4)-gg4],'r')
plt.plot(a4,n_auto4[0:len(n_auto4)-gg4],'ro')
plt.plot(a8,n_auto8[0:len(n_auto8)-gg8],'y')
plt.plot(a8,n_auto8[0:len(n_auto8)-gg8],'yo')
plt.plot(a16,n_auto16[0:len(n_auto16)-gg16],'g')
plt.plot(a16,n_auto16[0:len(n_auto16)-gg16],'go')
plt.plot(a32,n_auto32[0:len(n_auto32)-gg32],'b')
plt.plot(a32,n_auto32[0:len(n_auto32)-gg32],'bo')
plt.title(r'$\chi (t)$',fontsize=16)
plt.xlabel('log(MC Time per Site)',fontsize=16)
plt.text(3.7,0.5, r'L=4',color='red',fontsize=12)
plt.text(3.7,0.6, r'L=8',color='yellow',fontsize=12)
plt.text(3.7,0.7, r'L=16',color='green',fontsize=12)
plt.text(3.7,0.8, r'L=32',color='blue',fontsize=12)
plt.text(3.7,0.9, r'T=2.269',color='black',fontsize=12)
plt.xlim(-0.02,4.5)
plt.ylim(0,1.02)
savefig('/Users/onurkaplan/dropbox/kaplan/programs/graphics/properties/critical_slowing_metropolis_logtime_T=2,269.png')

# %%
Temp = 3.0
J = 1.0 / Temp
H= 0.0
L = 32
N=L*L
Nobs = 4
Nsw=4000
filename='correlated'

# %%
auto=np.zeros(Nsw)
    
auto=np.loadtxt('%s/autocorrelation/autocorrelation_fnct_energy_J%.2f_L%i_H%.2f' %(filename , J, L,H))

# %%
print len(auto)
# Out:
# 4000

# %%
x=linspace(0,Nsw-1,Nsw)
plt.plot(x,auto)
plt.title('Autocorrelation Function vs MC Time per Site',fontsize=12)
plt.xlabel('MC Time per Site',fontsize=12)
#plt.text(310, 0.2, r' m =$ \frac{1}{N} \sum s_i$',fontsize=18)
#plt.xlim(0,2)
#plt.ylim(-1,0.01)
#savefig('/Users/onurkaplan/desktop/graphics/autocorrelation/autocorrelation_T%f.png' %Temp )
plt.show()

# %%
j=0
n_autoT3_32=[]

while auto[j] > 0 :        
    n_autoT3_32.append(auto[j])
    j = j+1

# %%
print len(n_autoT3_32)
# Out:
# 15

# %%
5 17 12 8

# %%
ggT3_4=5
aT3_4 = np.log(np.linspace(1,len(n_autoT3_4)-1-ggT3_4,len(n_autoT3_4)-ggT3_4))
ggT3_8=17
aT3_8 = np.log(np.linspace(1,len(n_autoT3_8)-1-ggT3_8,len(n_autoT3_8)-ggT3_8))
ggT3_16=12
aT3_16 = np.log(np.linspace(1,len(n_autoT3_16)-1-ggT3_16,len(n_autoT3_16)-ggT3_16))
ggT3_32=8
aT3_32 = np.log(np.linspace(1,len(n_autoT3_32)-1-ggT3_32,len(n_autoT3_32)-ggT3_32))

# %%
plt.plot(aT3_4,n_autoT3_4[0:len(n_autoT3_4)-ggT3_4],'r')
plt.plot(aT3_4,n_autoT3_4[0:len(n_autoT3_4)-ggT3_4],'ro')
plt.plot(aT3_8,n_autoT3_8[0:len(n_autoT3_8)-ggT3_8],'y')
plt.plot(aT3_8,n_autoT3_8[0:len(n_autoT3_8)-ggT3_8],'yo')
plt.plot(aT3_16,n_autoT3_16[0:len(n_autoT3_16)-ggT3_16],'g')
plt.plot(aT3_16,n_autoT3_16[0:len(n_autoT3_16)-ggT3_16],'go')
plt.plot(aT3_32,n_autoT3_32[0:len(n_autoT3_32)-ggT3_32],'b')
plt.plot(aT3_32,n_autoT3_32[0:len(n_autoT3_32)-ggT3_32],'bo')
plt.title(r'$\chi (t)$',fontsize=16)
plt.xlabel('log(MC Time per Site)',fontsize=16)
plt.text(1.4,0.5, r'L=4',color='red',fontsize=12)
plt.text(1.4,0.6, r'L=8',color='yellow',fontsize=12)
plt.text(1.4,0.7, r'L=16',color='green',fontsize=12)
plt.text(1.4,0.8, r'L=32',color='blue',fontsize=12)
plt.text(1.4,0.9, r'T=3.0',color='black',fontsize=12)
plt.xlim(-0.01,1.81)
plt.ylim(0,1.02)
savefig('/Users/onurkaplan/dropbox/kaplan/programs/graphics/properties/critical_slowing_metropolis_logtime_T=3.png')
